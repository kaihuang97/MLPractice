# %%
import numpy as np         # linear algebra
import sklearn as sk       # machine learning
import pandas as pd        # reading in data files, data cleaning
import matplotlib.pyplot as plt   # for plotting
import seaborn as sns      # visualization tool

file_id = 'letter-recognition.data'
link = 'https://archive.ics.uci.edu/ml/machine-learning-databases/letter-recognition/{FILE_ID}'
csv_url = link.format(FILE_ID = file_id)

data = pd.read_csv(csv_url)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19999 entries, 0 to 19998
# Data columns (total 17 columns):
# T      19999 non-null object
# 2      19999 non-null int64
# 8      19999 non-null int64
# 3      19999 non-null int64
# 5      19999 non-null int64
# 1      19999 non-null int64
# 8.1    19999 non-null int64
# 13     19999 non-null int64
# 0      19999 non-null int64
# 6      19999 non-null int64
# 6.1    19999 non-null int64
# 10     19999 non-null int64
# 8.2    19999 non-null int64
# 0.1    19999 non-null int64
# 8.3    19999 non-null int64
# 0.2    19999 non-null int64
# 8.4    19999 non-null int64
# dtypes: int64(16), object(1)
# memory usage: 2.6+ MB

# %%
data.columns = ['letter', 'hori', 'vert', 'width', 'height', 
                'pixels', 'x-bar', 'y-bar', 'x2bar', 'y2bar',
                'xybar', 'x2ybr', 'xy2br', 'x-ege', 'xegvy',
                'y-ege', 'yegvx']
data.head()
# Out:
#   letter  hori  vert  width  height  pixels  x-bar  y-bar  x2bar  y2bar  \
# 0      I     5    12      3       7       2     10      5      5      4
# 1      D     4    11      6       8       6     10      6      2      6
# 2      N     7    11      6       6       3      5      9      4      6
# 3      G     2     1      3       1       1      8      6      6      6
# 4      S     4    11      5       8       3      8      8      6      9
#
#    xybar  x2ybr  xy2br  x-ege  xegvy  y-ege  yegvx
# 0     13      3      9      2      8      4     10
# 1     10      3      7      3      7      3      9
# 2      4      4     10      6     10      2      8
# 3      6      5      9      1      7      5     10
# 4      5      6      6      0      8      9      7

# %%
def z_trans(data):
  return (data - data.mean()) / data.std()

cols = [i for i in data.columns if i not in ['letter']]
for col in cols:
  data[col] = pd.to_numeric(data[col])
  data[col] = z_trans(data[col])
  
data.head()
# Out:
#   letter      hori      vert     width    height    pixels     x-bar  \
# 0      I  0.510321  1.502300 -1.053306  0.719686 -0.687522  1.531267
# 1      D -0.012362  1.199695  0.435847  1.161881  1.138595  1.531267
# 2      N  1.555687  1.199695  0.435847  0.277491 -0.230992 -0.936564
# 3      G -1.057728 -1.826362 -1.053306 -1.933484 -1.144051  0.544134
# 4      S -0.012362  1.199695 -0.060537  1.161881 -0.230992  0.544134
#
#       y-bar     x2bar     y2bar     xybar     x2ybr     xy2br     x-ege  \
# 0 -1.075304  0.137478 -0.495032  1.895867 -1.312733  0.514740 -0.448554
# 1 -0.645213 -0.973700  0.344995  0.690314 -1.312733 -0.446489 -0.019830
# 2  0.645062 -0.232915  0.344995 -1.720792 -0.932652  0.995354  1.266344
# 3 -0.645213  0.507871  0.344995 -0.917090 -0.552571  0.514740 -0.877279
# 4  0.214970  0.507871  1.605036 -1.318941 -0.172489 -0.927103 -1.306003
#
#       xegvy     y-ege     yegvx
# 0 -0.219082  0.120010  1.359380
# 1 -0.865595 -0.269549  0.741145
# 2  1.073944 -0.659109  0.122911
# 3 -0.865595  0.509569  1.359380
# 4 -0.219082  2.067806 -0.495323

# %% [markdown]
# Some general rules about the hidden layer are the following based on this paper:* Approximating Number of Hidden layer neurons in Multiple Hidden Layer BPNN Architecture* by Saurabh Karsoliya.
#
# In general:
#
# *   The number of hidden layer neurons are 2/3 (or 70% to 90%) of the size of the input layer.
# *   The number of hidden layer neurons should be less than twice of the number of neurons in input layer.
# *   The size of the hidden layer neurons is between the input layer size and the output layer size.

# %%
X = data.loc[:, data.columns != 'letter']
y = data['letter']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=0)

from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(17, 17, 17), random_state=0)
clf.fit(X_train, y_train)

y_pred_train = clf.predict(X_train)
y_pred_test = clf.predict(X_test)

from sklearn.metrics import accuracy_score
print('Training set R^2 =', accuracy_score(y_train, y_pred_train))
print('Test set R^2 =', accuracy_score(y_test, y_pred_test))
# Out:
# Training set R^2 = 0.872054503406463
# Test set R^2 = 0.85325

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(max_iter=100)

parameter_space = {
    'hidden_layer_sizes': [(17,17,17), (17,15,12), (17, 12, 5)],
    'activation': ['identity', 'logistic', 'tanh', 'relu'],
    'solver': ['sgd', 'adam', 'lbfgs'],
    'alpha': [0.0001, 0.001, 1e-5],
    'learning_rate': ['constant', 'adaptive', 'invscaling'],
    'random_state' : [0]
}

from sklearn.model_selection import GridSearchCV

clf = GridSearchCV(mlp, parameter_space, n_jobs=-1, cv=3)
clf.fit(X_train, y_train)

# Best paramete set
print('Best parameters found:\n', clf.best_params_)

# All results
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
    
y_true, y_pred = y_test , clf.predict(X_test)

from sklearn.metrics import classification_report
print('Results on the test set:')
print(classification_report(y_true, y_pred))
# Out:
# Best parameters found:
#  {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.739 (+/-0.004) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.766 (+/-0.004) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.769 (+/-0.008) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.739 (+/-0.004) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.766 (+/-0.004) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.769 (+/-0.008) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.065 (+/-0.007) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.766 (+/-0.004) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.769 (+/-0.008) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.724 (+/-0.007) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.756 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.766 (+/-0.007) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.724 (+/-0.007) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.756 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.766 (+/-0.007) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.082 (+/-0.006) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.756 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.766 (+/-0.007) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.627 (+/-0.020) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.655 (+/-0.013) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.663 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.627 (+/-0.020) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.655 (+/-0.013) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.663 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.094 (+/-0.007) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.655 (+/-0.013) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.663 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.739 (+/-0.003) for {'activation': 'identity', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.766 (+/-0.004) for {'activation': 'identity', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.769 (+/-0.008) for {'activation': 'identity', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.739 (+/-0.003) for {'activation': 'identity', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.766 (+/-0.004) for {'activation': 'identity', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.769 (+/-0.008) for {'activation': 'identity', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.065 (+/-0.007) for {'activation': 'identity', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.766 (+/-0.004) for {'activation': 'identity', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.769 (+/-0.008) for {'activation': 'identity', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.724 (+/-0.007) for {'activation': 'identity', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.756 (+/-0.010) for {'activation': 'identity', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.765 (+/-0.008) for {'activation': 'identity', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.724 (+/-0.007) for {'activation': 'identity', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.756 (+/-0.010) for {'activation': 'identity', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.765 (+/-0.008) for {'activation': 'identity', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.082 (+/-0.006) for {'activation': 'identity', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.756 (+/-0.010) for {'activation': 'identity', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.765 (+/-0.008) for {'activation': 'identity', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.627 (+/-0.020) for {'activation': 'identity', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.655 (+/-0.013) for {'activation': 'identity', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.663 (+/-0.011) for {'activation': 'identity', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.627 (+/-0.020) for {'activation': 'identity', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.655 (+/-0.013) for {'activation': 'identity', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.663 (+/-0.011) for {'activation': 'identity', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.094 (+/-0.007) for {'activation': 'identity', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.655 (+/-0.013) for {'activation': 'identity', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.663 (+/-0.011) for {'activation': 'identity', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.739 (+/-0.004) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.766 (+/-0.004) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.769 (+/-0.008) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.739 (+/-0.004) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.766 (+/-0.004) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.769 (+/-0.008) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.065 (+/-0.007) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.766 (+/-0.004) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.769 (+/-0.008) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.724 (+/-0.007) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.756 (+/-0.010) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.766 (+/-0.010) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.724 (+/-0.007) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.756 (+/-0.010) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.766 (+/-0.010) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.082 (+/-0.006) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.756 (+/-0.010) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.766 (+/-0.010) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.627 (+/-0.020) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.655 (+/-0.013) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.663 (+/-0.010) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.627 (+/-0.020) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.655 (+/-0.013) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.663 (+/-0.010) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.094 (+/-0.007) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.655 (+/-0.013) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.663 (+/-0.010) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.041 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.610 (+/-0.013) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.753 (+/-0.025) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.041 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.610 (+/-0.013) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.753 (+/-0.025) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.038 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.610 (+/-0.013) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.753 (+/-0.025) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.040 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.620 (+/-0.015) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.737 (+/-0.005) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.040 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.620 (+/-0.015) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.737 (+/-0.005) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.040 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.620 (+/-0.015) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.737 (+/-0.005) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.041 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.387 (+/-0.010) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.585 (+/-0.009) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.041 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.387 (+/-0.010) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.585 (+/-0.009) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.041 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.387 (+/-0.010) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.585 (+/-0.009) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.041 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.609 (+/-0.017) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.751 (+/-0.025) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.041 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.609 (+/-0.017) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.751 (+/-0.025) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.038 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.609 (+/-0.017) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.751 (+/-0.025) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.040 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.619 (+/-0.013) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.740 (+/-0.008) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.040 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.619 (+/-0.013) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.740 (+/-0.008) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.040 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.619 (+/-0.013) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.740 (+/-0.008) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.041 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.387 (+/-0.010) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.571 (+/-0.021) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.041 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.387 (+/-0.010) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.571 (+/-0.021) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.041 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.387 (+/-0.010) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.571 (+/-0.021) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.041 (+/-0.000) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.610 (+/-0.013) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.754 (+/-0.024) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.041 (+/-0.000) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.610 (+/-0.013) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.754 (+/-0.024) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.038 (+/-0.000) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.610 (+/-0.013) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.754 (+/-0.024) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.040 (+/-0.000) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.620 (+/-0.016) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.740 (+/-0.012) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.040 (+/-0.000) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.620 (+/-0.016) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.740 (+/-0.012) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.040 (+/-0.000) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.620 (+/-0.016) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.740 (+/-0.012) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.041 (+/-0.000) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.387 (+/-0.011) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.578 (+/-0.018) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.041 (+/-0.000) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.387 (+/-0.011) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.578 (+/-0.018) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.041 (+/-0.000) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.387 (+/-0.011) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.578 (+/-0.018) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.671 (+/-0.006) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.854 (+/-0.009) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.849 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.671 (+/-0.006) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.854 (+/-0.009) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.849 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.021 (+/-0.002) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.854 (+/-0.009) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.849 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.627 (+/-0.009) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.829 (+/-0.009) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.819 (+/-0.008) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.627 (+/-0.009) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.829 (+/-0.009) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.819 (+/-0.008) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.029 (+/-0.003) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.829 (+/-0.009) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.819 (+/-0.008) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.442 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.737 (+/-0.006) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.748 (+/-0.002) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.442 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.737 (+/-0.006) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.748 (+/-0.002) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.054 (+/-0.005) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.737 (+/-0.006) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.748 (+/-0.002) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.671 (+/-0.006) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.854 (+/-0.009) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.848 (+/-0.005) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.671 (+/-0.006) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.854 (+/-0.009) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.848 (+/-0.005) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.021 (+/-0.002) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.854 (+/-0.009) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.848 (+/-0.005) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.627 (+/-0.009) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.829 (+/-0.009) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.819 (+/-0.007) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.627 (+/-0.009) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.829 (+/-0.009) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.819 (+/-0.007) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.029 (+/-0.003) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.829 (+/-0.009) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.819 (+/-0.007) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.442 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.737 (+/-0.006) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.747 (+/-0.001) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.442 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.737 (+/-0.006) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.747 (+/-0.001) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.054 (+/-0.005) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.737 (+/-0.006) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.747 (+/-0.001) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.671 (+/-0.006) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.854 (+/-0.009) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.848 (+/-0.005) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.671 (+/-0.006) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.854 (+/-0.009) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.848 (+/-0.005) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.021 (+/-0.002) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.854 (+/-0.009) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.848 (+/-0.005) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.627 (+/-0.009) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.830 (+/-0.009) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.819 (+/-0.010) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.627 (+/-0.009) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.830 (+/-0.009) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.819 (+/-0.010) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.029 (+/-0.003) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.830 (+/-0.009) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.819 (+/-0.010) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.442 (+/-0.004) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.737 (+/-0.006) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.749 (+/-0.003) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.442 (+/-0.004) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.737 (+/-0.006) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.749 (+/-0.003) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.054 (+/-0.005) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.737 (+/-0.006) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.749 (+/-0.003) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.644 (+/-0.003) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.839 (+/-0.009) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.799 (+/-0.025) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.644 (+/-0.003) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.839 (+/-0.009) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.799 (+/-0.025) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.050 (+/-0.006) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.839 (+/-0.009) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.799 (+/-0.025) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.617 (+/-0.009) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.824 (+/-0.009) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.752 (+/-0.015) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.617 (+/-0.009) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.824 (+/-0.009) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.752 (+/-0.015) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.026 (+/-0.003) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.824 (+/-0.009) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.752 (+/-0.015) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.602 (+/-0.024) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.754 (+/-0.012) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.703 (+/-0.010) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.602 (+/-0.024) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.754 (+/-0.012) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.703 (+/-0.010) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.041 (+/-0.003) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.754 (+/-0.012) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.703 (+/-0.010) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.644 (+/-0.003) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.838 (+/-0.017) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.796 (+/-0.026) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.644 (+/-0.003) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.838 (+/-0.017) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.796 (+/-0.026) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.050 (+/-0.006) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.838 (+/-0.017) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.796 (+/-0.026) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.617 (+/-0.009) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.824 (+/-0.007) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.748 (+/-0.016) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.617 (+/-0.009) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.824 (+/-0.007) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.748 (+/-0.016) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.026 (+/-0.003) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.824 (+/-0.007) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.748 (+/-0.016) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.602 (+/-0.024) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.753 (+/-0.015) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.701 (+/-0.010) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.602 (+/-0.024) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.753 (+/-0.015) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.701 (+/-0.010) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.041 (+/-0.003) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.753 (+/-0.015) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.701 (+/-0.010) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.644 (+/-0.003) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.836 (+/-0.006) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.796 (+/-0.025) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.644 (+/-0.003) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.836 (+/-0.006) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.796 (+/-0.025) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.050 (+/-0.006) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.836 (+/-0.006) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.796 (+/-0.025) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.617 (+/-0.009) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.821 (+/-0.009) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.750 (+/-0.021) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.617 (+/-0.009) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.821 (+/-0.009) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.750 (+/-0.021) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.026 (+/-0.003) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.821 (+/-0.009) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.750 (+/-0.021) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 15, 12), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.602 (+/-0.024) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'sgd'}
# 0.754 (+/-0.011) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.705 (+/-0.024) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.602 (+/-0.024) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'sgd'}
# 0.754 (+/-0.011) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.705 (+/-0.024) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.041 (+/-0.003) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'sgd'}
# 0.754 (+/-0.011) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.705 (+/-0.024) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 12, 5), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# Results on the test set:
#               precision    recall  f1-score   support
#
#            A       0.96      0.91      0.93       165
#            B       0.81      0.85      0.83       157
#            C       0.91      0.87      0.89       145
#            D       0.81      0.89      0.85       169
#            E       0.84      0.87      0.85       156
#            F       0.87      0.85      0.86       156
#            G       0.80      0.85      0.82       151
#            H       0.79      0.81      0.80       135
#            I       0.97      0.84      0.90       140
#            J       0.91      0.91      0.91       143
#            K       0.80      0.87      0.84       146
#            L       0.91      0.90      0.91       165
#            M       0.91      0.92      0.92       159
#            N       0.88      0.90      0.89       146
#            O       0.85      0.74      0.79       164
#            P       0.89      0.89      0.89       157
#            Q       0.80      0.91      0.85       147
#            R       0.82      0.85      0.84       150
#            S       0.78      0.83      0.80       145
#            T       0.93      0.92      0.92       180
#            U       0.89      0.88      0.89       162
#            V       0.93      0.91      0.92       138
#            W       0.86      0.90      0.88       159
#            X       0.86      0.83      0.85       162
#            Y       0.95      0.89      0.92       159
#            Z       0.93      0.86      0.89       144
#
#    micro avg       0.87      0.87      0.87      4000
#    macro avg       0.87      0.87      0.87      4000
# weighted avg       0.87      0.87      0.87      4000
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
clf = MLPClassifier(activation='tanh', alpha=1e-05, hidden_layer_sizes=(17, 17, 17), 
                    learning_rate='constant', random_state=0, solver='adam', max_iter=1000)
clf.fit(X_train, y_train)

y_pred_train = clf.predict(X_train)
y_pred_test = clf.predict(X_test)

print('Training set R^2 =', accuracy_score(y_train, y_pred_train))
print('Test set R^2 =', accuracy_score(y_test, y_pred_test))
# Out:
# Training set R^2 = 0.939496218513657
# Test set R^2 = 0.91075

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(max_iter=1000)

parameter_space = {
    'hidden_layer_sizes': [(17,17,17)],
    'activation': ['tanh'],
    'solver': ['adam', 'lbfgs'],
    'alpha': [0.0001, 1e-5],
    'learning_rate': ['constant', 'adaptive', 'invscaling'],
    'random_state' : [0]
}

from sklearn.model_selection import GridSearchCV

clf = GridSearchCV(mlp, parameter_space, n_jobs=-1, cv=3)
clf.fit(X_train, y_train)

# Best paramete set
print('Best parameters found:\n', clf.best_params_)

# All results
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
    
y_true, y_pred = y_test , clf.predict(X_test)

from sklearn.metrics import classification_report
print('Results on the test set:')
print(classification_report(y_true, y_pred))
# Out:
# Best parameters found:
#  {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.891 (+/-0.014) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.877 (+/-0.012) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.891 (+/-0.014) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.877 (+/-0.012) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.891 (+/-0.014) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.877 (+/-0.012) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# 0.891 (+/-0.014) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'adam'}
# 0.879 (+/-0.008) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'constant', 'random_state': 0, 'solver': 'lbfgs'}
# 0.891 (+/-0.014) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'adam'}
# 0.879 (+/-0.008) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'adaptive', 'random_state': 0, 'solver': 'lbfgs'}
# 0.891 (+/-0.014) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'adam'}
# 0.879 (+/-0.008) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (17, 17, 17), 'learning_rate': 'invscaling', 'random_state': 0, 'solver': 'lbfgs'}
# Results on the test set:
#               precision    recall  f1-score   support
#
#            A       0.98      0.95      0.96       165
#            B       0.82      0.89      0.85       157
#            C       0.93      0.87      0.90       145
#            D       0.88      0.94      0.91       169
#            E       0.90      0.90      0.90       156
#            F       0.86      0.85      0.86       156
#            G       0.88      0.88      0.88       151
#            H       0.91      0.90      0.90       135
#            I       0.92      0.91      0.92       140
#            J       0.91      0.92      0.92       143
#            K       0.88      0.90      0.89       146
#            L       0.94      0.96      0.95       165
#            M       0.94      0.94      0.94       159
#            N       0.93      0.91      0.92       146
#            O       0.89      0.85      0.87       164
#            P       0.90      0.86      0.88       157
#            Q       0.92      0.95      0.93       147
#            R       0.87      0.89      0.88       150
#            S       0.90      0.89      0.90       145
#            T       0.92      0.93      0.93       180
#            U       0.94      0.91      0.92       162
#            V       0.94      0.91      0.92       138
#            W       0.93      0.95      0.94       159
#            X       0.90      0.91      0.91       162
#            Y       0.94      0.93      0.94       159
#            Z       0.96      0.97      0.96       144
#
#    micro avg       0.91      0.91      0.91      4000
#    macro avg       0.91      0.91      0.91      4000
# weighted avg       0.91      0.91      0.91      4000

# %%
clf = MLPClassifier(activation='tanh', alpha=0.0001, hidden_layer_sizes=(17, 17, 17), 
                    learning_rate='constant', random_state=0, solver='adam', max_iter=1000)
clf.fit(X_train, y_train)

y_pred_train = clf.predict(X_train)
y_pred_test = clf.predict(X_test)

print('Training set R^2 =', accuracy_score(y_train, y_pred_train))
print('Test set R^2 =', accuracy_score(y_test, y_pred_test))
# Out:
# Training set R^2 = 0.9395587224201513
# Test set R^2 = 0.9105
