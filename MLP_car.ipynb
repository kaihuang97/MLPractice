# %%
import numpy as np         # linear algebra
import sklearn as sk       # machine learning
import pandas as pd        # reading in data files, data cleaning
import matplotlib.pyplot as plt   # for plotting
import seaborn as sns      # visualization tool

file_id = 'car.data'
link = 'https://archive.ics.uci.edu/ml/machine-learning-databases/car/{FILE_ID}'
csv_url = link.format(FILE_ID = file_id)

data = pd.read_csv(csv_url)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1727 entries, 0 to 1726
# Data columns (total 7 columns):
# vhigh      1727 non-null object
# vhigh.1    1727 non-null object
# 2          1727 non-null object
# 2.1        1727 non-null object
# small      1727 non-null object
# low        1727 non-null object
# unacc      1727 non-null object
# dtypes: object(7)
# memory usage: 94.5+ KB

# %%
data.columns=['price', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'score']
data.head()
# Out:
#    price  maint doors persons lug_boot safety  score
# 0  vhigh  vhigh     2       2    small    med  unacc
# 1  vhigh  vhigh     2       2    small   high  unacc
# 2  vhigh  vhigh     2       2      med    low  unacc
# 3  vhigh  vhigh     2       2      med    med  unacc
# 4  vhigh  vhigh     2       2      med   high  unacc

# %%
data['price'].replace(['vhigh', 'high', 'med', 'low'], [4, 3, 2, 1], inplace=True)
data['lug_boot'].replace(['big', 'med', 'small'], [3, 2, 1], inplace=True)
data['maint'].replace(['vhigh', 'high', 'med', 'low'], [4, 3, 2, 1], inplace=True)
data['safety'].replace(['high', 'med', 'low'], [3, 2, 1], inplace=True)
data['doors'].replace(['2', '3', '4', '5more'], [2, 3, 4, 5], inplace=True)
data['persons'].replace(['2', '4', 'more'], [2, 4, 5], inplace=True)
data['score'].replace(['unacc', 'acc', 'good', 'vgood'], [1, 2, 3, 4], inplace=True)
data.head()
# Out:
#    price  maint  doors  persons  lug_boot  safety  score
# 0      4      4      2        2         1       2      1
# 1      4      4      2        2         1       3      1
# 2      4      4      2        2         2       1      1
# 3      4      4      2        2         2       2      1
# 4      4      4      2        2         2       3      1

# %%
def z_trans(data):
  return (data - data.mean()) / data.std()

data['p'] = z_trans(data['price'])
data['m'] = z_trans(data['maint'])
data['s'] = z_trans(data['safety'])
data['d'] = z_trans(data['doors'])
data['pp'] = z_trans(data['persons'])
data['lug'] = z_trans(data['lug_boot'])

data.head()
# Out:
#    price  maint  doors  persons  lug_boot  safety  score        p        m  \
# 0      4      4      2        2         1       2      1  1.34234  1.34234
# 1      4      4      2        2         1       3      1  1.34234  1.34234
# 2      4      4      2        2         2       1      1  1.34234  1.34234
# 3      4      4      2        2         2       2      1  1.34234  1.34234
# 4      4      4      2        2         2       3      1  1.34234  1.34234
#
#           s        d        pp       lug
# 0 -0.000709 -1.34234 -1.336997 -1.225277
# 1  1.223859 -1.34234 -1.336997 -1.225277
# 2 -1.225277 -1.34234 -1.336997 -0.000709
# 3 -0.000709 -1.34234 -1.336997 -0.000709
# 4  1.223859 -1.34234 -1.336997 -0.000709

# %% [markdown]
# Some general rules about the hidden layer are the following based on this paper:* Approximating Number of Hidden layer neurons in Multiple Hidden Layer BPNN Architecture* by Saurabh Karsoliya.
#
# In general:
#
# *   The number of hidden layer neurons are 2/3 (or 70% to 90%) of the size of the input layer.
# *   The number of hidden layer neurons should be less than twice of the number of neurons in input layer.
# *   The size of the hidden layer neurons is between the input layer size and the output layer size.

# %%
X = data[['p', 'm', 's', 'd', 'pp', 'lug']]
y = data['score']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=0)

from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(5, 2), random_state=1)
clf.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='relu', alpha=1e-05, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(5, 2), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=1, shuffle=True, solver='lbfgs', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
y_pred_train = clf.predict(X_train)
y_pred_test = clf.predict(X_test)

from sklearn.metrics import accuracy_score

print('Training set R^2 =', accuracy_score(y_train, y_pred_train))
print('Test set R^2 =', accuracy_score(y_test, y_pred_test))
# Out:
# Training set R^2 = 0.9160028964518465
# Test set R^2 = 0.8728323699421965

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(max_iter=100)

parameter_space = {
    'hidden_layer_sizes': [(3,3,3), (5,2), (3,2), (5,5), (5,6), (2,3), (3,3), (4,4), (6, 6, 6), (6, 6), (6, 2), (6, 3), (6, 4), (6, 5)],
    'activation': ['identity', 'logistic', 'tanh', 'relu'],
    'solver': ['sgd', 'adam', 'lbfgs'],
    'alpha': [0.0001, 0.05, 1e-5, 0.01, 0.001],
    'learning_rate': ['constant', 'adaptive', 'invscaling'],
}

from sklearn.model_selection import GridSearchCV

clf = GridSearchCV(mlp, parameter_space, n_jobs=-1, cv=3)
clf.fit(X_train, y_train)

# Best paramete set
print('Best parameters found:\n', clf.best_params_)

# All results
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
    
y_true, y_pred = y_test , clf.predict(X_test)

from sklearn.metrics import classification_report
print('Results on the test set:')
print(classification_report(y_true, y_pred))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Best parameters found:
#  {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.773 (+/-0.012) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.810 (+/-0.022) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.757 (+/-0.068) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.792 (+/-0.027) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.363 (+/-0.464) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.757 (+/-0.103) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.844 (+/-0.011) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.794 (+/-0.021) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.789 (+/-0.031) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.841 (+/-0.013) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.787 (+/-0.037) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.769 (+/-0.098) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.840 (+/-0.015) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.328 (+/-0.342) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.768 (+/-0.081) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.841 (+/-0.013) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.755 (+/-0.098) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.780 (+/-0.087) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.841 (+/-0.013) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.767 (+/-0.090) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.805 (+/-0.018) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.840 (+/-0.015) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.205 (+/-0.103) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.774 (+/-0.033) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.841 (+/-0.013) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.800 (+/-0.008) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.801 (+/-0.009) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.803 (+/-0.016) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.811 (+/-0.049) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.413 (+/-0.290) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.808 (+/-0.022) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.801 (+/-0.009) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.823 (+/-0.016) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.800 (+/-0.020) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.816 (+/-0.021) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.374 (+/-0.081) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.814 (+/-0.019) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.767 (+/-0.059) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.724 (+/-0.080) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.840 (+/-0.015) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.772 (+/-0.066) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.781 (+/-0.047) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.840 (+/-0.015) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.534 (+/-0.238) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.775 (+/-0.057) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.841 (+/-0.013) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.810 (+/-0.009) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.806 (+/-0.016) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.778 (+/-0.074) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.783 (+/-0.045) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.443 (+/-0.351) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.803 (+/-0.005) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.803 (+/-0.008) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.811 (+/-0.024) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.794 (+/-0.035) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.807 (+/-0.021) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.321 (+/-0.397) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.773 (+/-0.091) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.813 (+/-0.015) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.833 (+/-0.028) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.820 (+/-0.019) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.831 (+/-0.008) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.411 (+/-0.318) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.828 (+/-0.009) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.804 (+/-0.018) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 6), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.815 (+/-0.026) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 6), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 6), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.813 (+/-0.007) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 6), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.820 (+/-0.005) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 6), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 6), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.192 (+/-0.120) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 6), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.815 (+/-0.004) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 6), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 6), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.783 (+/-0.042) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.809 (+/-0.008) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.841 (+/-0.013) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 2), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.805 (+/-0.002) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.781 (+/-0.036) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.841 (+/-0.013) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 2), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.274 (+/-0.223) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 2), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.781 (+/-0.044) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 2), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.841 (+/-0.013) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 2), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.799 (+/-0.013) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 3), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.813 (+/-0.020) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 3), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 3), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.793 (+/-0.022) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 3), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.807 (+/-0.009) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 3), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 3), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.126 (+/-0.156) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 3), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.810 (+/-0.021) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 3), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 3), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.798 (+/-0.011) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 4), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.818 (+/-0.023) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 4), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 4), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.799 (+/-0.026) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 4), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.802 (+/-0.007) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 4), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 4), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.189 (+/-0.193) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 4), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.816 (+/-0.013) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 4), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 4), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.812 (+/-0.031) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 5), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.814 (+/-0.018) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 5), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 5), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.802 (+/-0.011) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 5), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.813 (+/-0.014) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 5), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 5), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.300 (+/-0.147) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 5), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.819 (+/-0.016) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 5), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 5), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.762 (+/-0.085) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.791 (+/-0.024) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.844 (+/-0.012) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.778 (+/-0.078) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.755 (+/-0.076) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.844 (+/-0.011) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.345 (+/-0.484) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.794 (+/-0.083) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.847 (+/-0.015) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.773 (+/-0.062) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.795 (+/-0.020) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.841 (+/-0.013) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.770 (+/-0.040) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.792 (+/-0.033) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.839 (+/-0.014) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.273 (+/-0.253) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.786 (+/-0.029) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.840 (+/-0.015) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.766 (+/-0.070) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.772 (+/-0.092) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.841 (+/-0.012) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.791 (+/-0.087) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.759 (+/-0.057) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.839 (+/-0.013) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.337 (+/-0.367) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.759 (+/-0.084) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.839 (+/-0.013) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.794 (+/-0.041) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.812 (+/-0.025) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.805 (+/-0.030) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.810 (+/-0.010) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.364 (+/-0.245) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.815 (+/-0.025) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.845 (+/-0.012) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.814 (+/-0.016) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.809 (+/-0.006) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.812 (+/-0.014) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.825 (+/-0.012) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.846 (+/-0.011) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.206 (+/-0.300) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.808 (+/-0.034) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.740 (+/-0.071) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.756 (+/-0.080) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.840 (+/-0.011) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.807 (+/-0.029) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.755 (+/-0.081) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.840 (+/-0.015) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.343 (+/-0.169) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.773 (+/-0.104) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.841 (+/-0.013) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.796 (+/-0.015) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.764 (+/-0.107) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.846 (+/-0.013) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.755 (+/-0.073) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.735 (+/-0.056) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.230 (+/-0.331) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.739 (+/-0.103) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.845 (+/-0.012) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.804 (+/-0.015) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.802 (+/-0.009) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.788 (+/-0.042) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.792 (+/-0.032) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.845 (+/-0.012) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.339 (+/-0.228) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.791 (+/-0.043) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.813 (+/-0.024) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.835 (+/-0.007) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.806 (+/-0.004) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.836 (+/-0.012) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.845 (+/-0.012) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.272 (+/-0.282) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.825 (+/-0.029) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.786 (+/-0.067) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 6), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.820 (+/-0.032) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 6), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 6), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.799 (+/-0.015) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 6), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.815 (+/-0.007) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 6), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.845 (+/-0.012) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 6), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.329 (+/-0.452) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 6), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.816 (+/-0.015) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 6), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.846 (+/-0.011) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 6), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.798 (+/-0.027) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.781 (+/-0.064) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.840 (+/-0.015) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 2), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.807 (+/-0.027) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.786 (+/-0.055) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.840 (+/-0.015) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 2), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.287 (+/-0.411) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 2), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.765 (+/-0.065) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 2), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.839 (+/-0.013) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 2), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.793 (+/-0.041) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 3), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.810 (+/-0.010) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 3), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.845 (+/-0.012) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 3), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.802 (+/-0.015) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 3), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.811 (+/-0.015) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 3), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 3), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.307 (+/-0.322) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 3), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.800 (+/-0.043) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 3), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.846 (+/-0.013) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 3), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.778 (+/-0.096) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 4), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.816 (+/-0.017) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 4), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 4), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.806 (+/-0.014) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 4), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.814 (+/-0.008) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 4), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 4), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.336 (+/-0.227) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 4), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.817 (+/-0.032) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 4), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 4), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.795 (+/-0.035) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 5), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.817 (+/-0.022) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 5), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 5), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.799 (+/-0.004) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 5), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.806 (+/-0.019) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 5), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 5), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.400 (+/-0.148) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 5), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.824 (+/-0.009) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 5), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 5), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.761 (+/-0.062) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.805 (+/-0.018) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.849 (+/-0.015) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.787 (+/-0.053) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.815 (+/-0.007) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.846 (+/-0.011) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.225 (+/-0.256) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.765 (+/-0.088) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.847 (+/-0.013) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.747 (+/-0.064) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.791 (+/-0.034) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.841 (+/-0.013) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.774 (+/-0.084) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.806 (+/-0.010) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.841 (+/-0.013) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.259 (+/-0.336) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.781 (+/-0.113) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.841 (+/-0.013) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.753 (+/-0.030) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.783 (+/-0.070) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.841 (+/-0.013) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.762 (+/-0.043) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.789 (+/-0.055) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.841 (+/-0.013) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.287 (+/-0.138) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.726 (+/-0.040) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.841 (+/-0.013) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.807 (+/-0.047) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.812 (+/-0.019) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.792 (+/-0.021) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.809 (+/-0.029) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.280 (+/-0.165) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.815 (+/-0.021) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.785 (+/-0.021) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.818 (+/-0.004) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.800 (+/-0.018) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.823 (+/-0.022) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.229 (+/-0.378) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.818 (+/-0.015) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.755 (+/-0.098) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.763 (+/-0.084) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.841 (+/-0.013) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.728 (+/-0.050) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.723 (+/-0.046) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.841 (+/-0.013) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.344 (+/-0.445) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.769 (+/-0.047) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.841 (+/-0.013) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.750 (+/-0.074) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.760 (+/-0.077) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.810 (+/-0.014) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.806 (+/-0.033) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.846 (+/-0.011) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.396 (+/-0.436) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.759 (+/-0.063) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.844 (+/-0.016) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.794 (+/-0.018) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.806 (+/-0.013) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.791 (+/-0.031) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.813 (+/-0.012) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.350 (+/-0.211) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.802 (+/-0.013) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.846 (+/-0.011) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.819 (+/-0.015) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.836 (+/-0.007) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.800 (+/-0.067) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.834 (+/-0.013) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.337 (+/-0.220) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.834 (+/-0.016) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.846 (+/-0.010) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.804 (+/-0.010) for {'activation': 'identity', 'alpha': 1e-05, 'hidden_layer_sizes': (6, 6), 'learning_rate': 'constant', 'solver': 'sgd'}
# ...
# 0.940 (+/-0.030) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.350 (+/-0.503) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.524 (+/-0.682) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.845 (+/-0.200) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.710 (+/-0.017) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.740 (+/-0.059) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.909 (+/-0.006) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.702 (+/-0.004) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.760 (+/-0.085) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.892 (+/-0.032) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.501 (+/-0.571) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.660 (+/-0.119) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.916 (+/-0.023) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.702 (+/-0.004) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.751 (+/-0.103) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.942 (+/-0.014) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.717 (+/-0.043) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.815 (+/-0.082) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.945 (+/-0.013) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.120 (+/-0.186) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.828 (+/-0.004) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.949 (+/-0.041) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.715 (+/-0.034) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.807 (+/-0.027) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.910 (+/-0.067) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.703 (+/-0.002) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.787 (+/-0.061) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.950 (+/-0.024) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.178 (+/-0.190) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.805 (+/-0.025) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.946 (+/-0.046) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.706 (+/-0.006) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.748 (+/-0.075) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.865 (+/-0.029) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.704 (+/-0.000) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.698 (+/-0.016) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.881 (+/-0.050) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.099 (+/-0.175) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.726 (+/-0.025) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.891 (+/-0.035) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.702 (+/-0.004) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.753 (+/-0.076) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.917 (+/-0.017) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.721 (+/-0.049) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.546 (+/-0.460) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.925 (+/-0.032) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.287 (+/-0.478) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.702 (+/-0.007) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.918 (+/-0.017) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.706 (+/-0.013) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.736 (+/-0.090) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.924 (+/-0.001) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.702 (+/-0.004) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.745 (+/-0.099) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.931 (+/-0.021) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.217 (+/-0.291) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.748 (+/-0.095) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.944 (+/-0.024) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.702 (+/-0.004) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.781 (+/-0.117) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.953 (+/-0.018) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.702 (+/-0.004) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.839 (+/-0.008) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.922 (+/-0.053) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.364 (+/-0.351) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.827 (+/-0.042) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.962 (+/-0.016) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.786 (+/-0.091) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 6), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.802 (+/-0.078) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 6), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.954 (+/-0.041) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 6), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.723 (+/-0.053) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 6), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.815 (+/-0.015) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 6), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.958 (+/-0.018) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 6), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.266 (+/-0.617) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 6), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.804 (+/-0.066) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 6), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.950 (+/-0.028) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 6), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.718 (+/-0.041) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.739 (+/-0.105) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.941 (+/-0.010) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 2), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.702 (+/-0.004) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.746 (+/-0.113) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.921 (+/-0.021) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 2), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.204 (+/-0.429) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 2), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.810 (+/-0.028) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 2), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.914 (+/-0.049) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 2), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.713 (+/-0.027) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 3), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.751 (+/-0.107) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 3), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.930 (+/-0.018) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 3), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.742 (+/-0.043) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 3), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.781 (+/-0.116) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 3), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.941 (+/-0.035) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 3), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.263 (+/-0.290) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 3), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.733 (+/-0.050) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 3), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.933 (+/-0.036) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 3), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.731 (+/-0.066) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 4), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.743 (+/-0.086) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 4), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.935 (+/-0.054) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 4), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.705 (+/-0.011) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 4), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.777 (+/-0.113) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 4), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.953 (+/-0.035) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 4), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.450 (+/-0.387) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 4), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.831 (+/-0.055) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 4), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.946 (+/-0.015) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 4), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.706 (+/-0.006) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 5), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.841 (+/-0.015) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 5), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.932 (+/-0.026) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 5), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.726 (+/-0.064) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 5), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.818 (+/-0.014) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 5), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.938 (+/-0.021) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 5), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.136 (+/-0.165) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 5), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.739 (+/-0.107) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 5), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.928 (+/-0.072) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (6, 5), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# Results on the test set:
#               precision    recall  f1-score   support
#
#            1       0.99      0.99      0.99       239
#            2       0.91      0.94      0.92        77
#            3       0.82      0.64      0.72        14
#            4       0.69      0.69      0.69        16
#
#    micro avg       0.95      0.95      0.95       346
#    macro avg       0.85      0.81      0.83       346
# weighted avg       0.95      0.95      0.95       346

# %%
clf = MLPClassifier(activation='tanh', alpha=0.01, hidden_layer_sizes=(5, 5), learning_rate='invscaling', solver='lbfgs')

clf.fit(X_train, y_train)

y_pred_train = clf.predict(X_train)
y_pred_test = clf.predict(X_test)

print('Model ran', clf.n_iter_, 'iterations using', clf.out_activation_, 'function')
print('loss =', clf.loss_)
print('Training set R^2 =', accuracy_score(y_train, y_pred_train))
print('Test set R^2 =', accuracy_score(y_test, y_pred_test))
print('coefficients =', clf.coefs_)
# Out:
# Model ran 201 iterations using softmax function
# loss = 0.016453678620426935
# Training set R^2 = 0.9942070963070239
# Test set R^2 = 0.9884393063583815
# coefficients = [array([[-3.6083916 , -0.05708744,  0.04287446, -4.09568286,  4.5456664 ],
#        [ 0.46741491, -0.06099174,  0.03186461, -3.84666479,  4.3088371 ],
#        [-5.08217235,  6.14873563,  0.51743006, -1.08129268,  0.24500454],
#        [-0.05004012, -0.19771971,  0.19527946,  0.14225162,  0.04687904],
#        [-1.86377776,  6.74861008, -0.11416303, -2.23700146, -0.05838594],
#        [-0.46764833, -0.53283164,  0.45474734, -0.44172129,  0.16140118]]), array([[-2.54267018, -1.84470041,  0.43096763, -0.76810462, -1.99864309],
#        [ 2.24598036, -1.65437016,  3.72352202, -0.00640185,  2.1706632 ],
#        [ 4.98811218,  4.02654404,  3.93753102, -4.16746593,  0.1933029 ],
#        [-2.13614723, -0.1298306 ,  3.47708563, -0.16756904,  0.51911859],
#        [ 1.77332583, -5.34665323, -0.95956788,  2.78544961, -4.39429169]]), array([[-3.33580854,  2.03678333, -3.56826037,  6.21350063],
#        [ 0.47899653, -5.0975223 ,  2.40309045,  3.01704694],
#        [-9.69042889,  5.35648739,  2.39859356,  0.63418181],
#        [ 4.26716999,  2.63006581, -3.82538629, -3.98123221],
#        [-0.94205978, -4.26763513,  0.72077809,  3.85008746]])]
