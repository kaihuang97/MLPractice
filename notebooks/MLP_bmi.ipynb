# %%
import numpy as np         # linear algebra
import sklearn as sk       # machine learning
import pandas as pd        # reading in data files, data cleaning
import matplotlib.pyplot as plt   # for plotting
import seaborn as sns      # visualization tool

file_id = '172V7yK-DjsxoaejDlOEl9S1R4A_GdP7U'
link = 'https://drive.google.com/uc?export=download&id={FILE_ID}'
csv_url = link.format(FILE_ID = file_id)

data = pd.read_csv(csv_url)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
# Gender    500 non-null object
# Height    500 non-null int64
# Weight    500 non-null int64
# Index     500 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 15.7+ KB

# %%
data.head()
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4
# 3  Female     195     104      3
# 4    Male     149      61      3

# %% [markdown]
#         0 - extremely weak
#         1 - weak
#         2 - normal
#         3 - overweight
#         4 - obese
#         5 - extremely obese

# %%
data['Sex'] = data['Gender']
data['Sex'].replace(['Female', 'Male'], [0, 1], inplace=True)

data.head()
# Out:
#    Gender  Height  Weight  Index  Sex
# 0    Male     174      96      4    1
# 1    Male     189      87      2    1
# 2  Female     185     110      4    0
# 3  Female     195     104      3    0
# 4    Male     149      61      3    1

# %%
height_m = 0.01 * data['Height'] 
data['BMI'] = data['Weight'] / height_m**2

data.head()
# Out:
#    Gender  Height  Weight  Index  Sex        BMI
# 0    Male     174      96      4    1  31.708284
# 1    Male     189      87      2    1  24.355421
# 2  Female     185     110      4    0  32.140248
# 3  Female     195     104      3    0  27.350427
# 4    Male     149      61      3    1  27.476240

# %%
def z_trans(data):
  return (data - data.mean()) / data.std()

data['H'] = z_trans(data['Height'])
data['W'] = z_trans(data['Weight'])

data.head()
# Out:
#    Gender  Height  Weight  Index  Sex        BMI         H         W
# 0    Male     174      96      4    1  31.708284  0.247691 -0.308808
# 1    Male     189      87      2    1  24.355421  1.163707 -0.586735
# 2  Female     185     110      4    0  32.140248  0.919436  0.123523
# 3  Female     195     104      3    0  27.350427  1.530113 -0.061762
# 4    Male     149      61      3    1  27.476240 -1.279003 -1.389635

# %%
X = data[['Sex', 'H', 'W']]
y = data['Index']

# %%
data['zBMI'] = z_trans(data['BMI']);

data.head()
# Out:
#    Gender  Height  Weight  Index  Sex        BMI         H         W      zBMI
# 0    Male     174      96      4    1  31.708284  0.247691 -0.308808 -0.433708
# 1    Male     189      87      2    1  24.355421  1.163707 -0.586735 -0.960205
# 2  Female     185     110      4    0  32.140248  0.919436  0.123523 -0.402777
# 3  Female     195     104      3    0  27.350427  1.530113 -0.061762 -0.745750
# 4    Male     149      61      3    1  27.476240 -1.279003 -1.389635 -0.736741

# %%
from sklearn.neural_network import MLPClassifier
X_3 = data[['H', 'W', 'zBMI']]
y = data['Index']


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_3, y, test_size = 0.2, random_state=0)


clf = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(3, 3), random_state=1)
clf.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='relu', alpha=1e-05, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(3, 3), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=1, shuffle=True, solver='lbfgs', tol=0.0001,
#        validation_fraction=0.1, verbose=False, warm_start=False)

# %%
y_pred_train = clf.predict(X_train)
y_pred_test = clf.predict(X_test)

# [coef.shape for coef in clf.coefs_]
# clf.predict_proba(X_test)

# %%
from sklearn.metrics import accuracy_score

print('Training set R^2 =', accuracy_score(y_train, y_pred_train))
print('Test set R^2 =', accuracy_score(y_test, y_pred_test))
# Out:
# Training set R^2 = 0.9375
# Test set R^2 = 0.94

# %% [markdown]
# Some general rules about the hidden layer are the following based on this paper:* Approximating Number of Hidden layer neurons in Multiple Hidden Layer BPNN Architecture* by Saurabh Karsoliya.
#
# In general:
#
# *   The number of hidden layer neurons are 2/3 (or 70% to 90%) of the size of the input layer.
# *   The number of hidden layer neurons should be less than twice of the number of neurons in input layer.
# *   The size of the hidden layer neurons is between the input layer size and the output layer size.

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(max_iter=100)

parameter_space = {
    'hidden_layer_sizes': [(3,3,3), (5,2), (3,2), (5,5), (5,6), (2,3), (3,3), (4,4)],
    'activation': ['identity', 'logistic', 'tanh', 'relu'],
    'solver': ['sgd', 'adam', 'lbfgs'],
    'alpha': [0.0001, 0.05, 1e-5, 0.01, 0.001],
    'learning_rate': ['constant', 'adaptive', 'invscaling'],
}

from sklearn.model_selection import GridSearchCV

clf = GridSearchCV(mlp, parameter_space, n_jobs=-1, cv=3)
clf.fit(X_train, y_train)

# Best paramete set
print('Best parameters found:\n', clf.best_params_)

# All results
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
    
y_true, y_pred = y_test , clf.predict(X_test)

from sklearn.metrics import classification_report
print('Results on the test set:')
print(classification_report(y_true, y_pred))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Best parameters found:
#  {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.545 (+/-0.188) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.367 (+/-0.289) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.943 (+/-0.019) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.580 (+/-0.117) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.463 (+/-0.263) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.943 (+/-0.032) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.128 (+/-0.140) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.438 (+/-0.036) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.950 (+/-0.019) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.598 (+/-0.116) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.477 (+/-0.294) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.938 (+/-0.018) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.487 (+/-0.081) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.540 (+/-0.093) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.945 (+/-0.026) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.323 (+/-0.218) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.310 (+/-0.374) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.925 (+/-0.041) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.525 (+/-0.163) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.287 (+/-0.377) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.938 (+/-0.013) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.370 (+/-0.325) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.505 (+/-0.213) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.945 (+/-0.015) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.122 (+/-0.171) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.335 (+/-0.193) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.950 (+/-0.008) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.618 (+/-0.172) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.490 (+/-0.154) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.938 (+/-0.009) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.590 (+/-0.064) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.625 (+/-0.033) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.935 (+/-0.006) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.158 (+/-0.224) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.532 (+/-0.179) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.938 (+/-0.018) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.578 (+/-0.119) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.590 (+/-0.167) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.950 (+/-0.020) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.552 (+/-0.216) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.522 (+/-0.096) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.940 (+/-0.011) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.152 (+/-0.176) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.670 (+/-0.159) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.938 (+/-0.013) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.472 (+/-0.103) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.282 (+/-0.337) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.932 (+/-0.046) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.552 (+/-0.026) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.372 (+/-0.350) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.948 (+/-0.024) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.195 (+/-0.243) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.445 (+/-0.110) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.945 (+/-0.030) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.645 (+/-0.153) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.500 (+/-0.175) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.948 (+/-0.012) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.480 (+/-0.025) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.325 (+/-0.432) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.953 (+/-0.030) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.295 (+/-0.251) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.525 (+/-0.179) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.945 (+/-0.026) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.515 (+/-0.171) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.562 (+/-0.073) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.950 (+/-0.006) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.580 (+/-0.104) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.287 (+/-0.334) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.932 (+/-0.002) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.155 (+/-0.110) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.515 (+/-0.378) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.945 (+/-0.015) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.492 (+/-0.104) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.527 (+/-0.074) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.948 (+/-0.024) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.435 (+/-0.039) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.595 (+/-0.215) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.948 (+/-0.012) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.215 (+/-0.270) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.490 (+/-0.145) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.943 (+/-0.008) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0
for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.580 (+/-0.039) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.925 (+/-0.031) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.260 (+/-0.219) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.237 (+/-0.287) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.920 (+/-0.069) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.420 (+/-0.011) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.255 (+/-0.218) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.865 (+/-0.206) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.140 (+/-0.175) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.347 (+/-0.183) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.740 (+/-0.462) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.453 (+/-0.146) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.302 (+/-0.407) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.922 (+/-0.074) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.405 (+/-0.010) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.302 (+/-0.299) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.672 (+/-0.432) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.117 (+/-0.052) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.448 (+/-0.372) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.885 (+/-0.067) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.557 (+/-0.192) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.412 (+/-0.021) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.917 (+/-0.023) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.510 (+/-0.158) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.458 (+/-0.307) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.910 (+/-0.030) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.210 (+/-0.279) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.495 (+/-0.245) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.945 (+/-0.015) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.405 (+/-0.010) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.517 (+/-0.308) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.535 (+/-0.357) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.432 (+/-0.070) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.320 (+/-0.243) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.730 (+/-0.446) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.215 (+/-0.341) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.320 (+/-0.360) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.675 (+/-0.389) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 3, 3), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.328 (+/-0.253) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.445 (+/-0.146) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.927 (+/-0.042) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.235 (+/-0.327) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.343 (+/-0.327) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.925 (+/-0.044) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.145 (+/-0.162) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.230 (+/-0.314) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.875 (+/-0.068) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.443 (+/-0.071) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.158 (+/-0.314) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.752 (+/-0.475) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.422 (+/-0.036) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.450 (+/-0.114) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.927 (+/-0.014) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.205 (+/-0.260) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.378 (+/-0.378) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.820 (+/-0.177) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 2), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.405 (+/-0.010) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.507 (+/-0.312) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.845 (+/-0.200) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.468 (+/-0.062) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.375 (+/-0.218) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.917 (+/-0.037) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.068 (+/-0.105) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.490 (+/-0.300) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.912 (+/-0.049) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.520 (+/-0.131) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.630 (+/-0.224) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.927 (+/-0.019) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.458 (+/-0.075) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.398 (+/-0.029) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.938 (+/-0.020) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.107 (+/-0.118) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.482 (+/-0.120) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.917 (+/-0.030) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 6), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.338 (+/-0.258) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.393 (+/-0.039) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.930 (+/-0.029) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.352 (+/-0.151) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.525 (+/-0.071) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.755 (+/-0.500) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.217 (+/-0.300) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.485 (+/-0.137) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.920 (+/-0.035) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (2, 3), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.448 (+/-0.076) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.357 (+/-0.351) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.912 (+/-0.017) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.407 (+/-0.011) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.305 (+/-0.114) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.917 (+/-0.047) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.245 (+/-0.301) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.367 (+/-0.230) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.932 (+/-0.043) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (3, 3), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# 0.472 (+/-0.125) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.395 (+/-0.253) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.943 (+/-0.037) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.495 (+/-0.189) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.430 (+/-0.063) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.925 (+/-0.021) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.233 (+/-0.251) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# 0.318 (+/-0.156) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'invscaling', 'solver': 'adam'}
# 0.892 (+/-0.105) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (4, 4), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# Results on the test set:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#            1       0.57      1.00      0.73         4
#            2       1.00      0.90      0.95        10
#            3       0.88      1.00      0.94        15
#            4       1.00      0.91      0.95        32
#            5       0.95      1.00      0.97        36
#
#    micro avg       0.93      0.93      0.93       100
#    macro avg       0.73      0.80      0.76       100
# weighted avg       0.92      0.93      0.92       100
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
clf = MLPClassifier(activation='tanh', alpha=0.05, hidden_layer_sizes=(4, 4), learning_rate='adaptive', solver='lbfgs')
clf.fit(X_train, y_train)

y_pred_train = clf.predict(X_train)
y_pred_test = clf.predict(X_test)

print('Training set R^2 =', accuracy_score(y_train, y_pred_train))
print('Test set R^2 =', accuracy_score(y_test, y_pred_test))
# Out:
# Training set R^2 = 0.9725
# Test set R^2 = 0.97
